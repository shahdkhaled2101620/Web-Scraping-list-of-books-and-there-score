# %%
import requests
from bs4 import BeautifulSoup

# %%
link='https://www.goodreads.com/list/show/153860.Goodreads_Top_100_Highest_Rated_Books_on_Goodreads_with_at_least_10_000_Ratings'

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}


page = requests.get(link, headers=headers)

# %%
#page = requests.get(link) #connect to website

# %%
page # this means the request is ok
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'html.parser') #get html code

# %%
book = soup.find_all('tr', itemtype="http://schema.org/Book")

# %%
for i in book:
    btitle=i.find('span',{'itemprop':"name"})
    auther=i.find('span',{'itemprop':"author"})
    score=i.find('a',{"href":"#"})
    #print(score.text.strip())

# %%
import pandas as pd

# %%
data=[]

# %%
for i in book:
    btitle=i.find('span',{'itemprop':"name"})
    auther=i.find('span',{'itemprop':"author"})
    score=i.find('a',{"href":"#"})

    data.append({
        #علشان لو عنصر مش موجود → البرنامج ما يقعش
        "Tilte": btitle.text.strip() if btitle else None,
        "Auther": auther.text.strip() if auther else None,
        "Score": score.text.strip() if score else None
    })

# %%
df=pd.DataFrame(data)
df
# Out:
#                                                 Tilte  \
# 0      Words of Radiance (The Stormlight Archive, #2)
# 1   Harry Potter and the Deathly Hallows (Harry Po...
# 2                      Fourth Wing (The Empyrean, #1)
# 3                  Crooked Kingdom (Six of Crows, #2)
# 4   A Court of Mist and Fury (A Court of Thorns an...
# ..                                                ...
# 95                                    ギヴン 2 [Given 2]
# 96  A Killer of Influence (DCI Logan Crime Thrille...
# 97                                     Losin' Control
# 98                     Midnight Black (Gray Man, #14)
# 99                                        Hold Strong
#
#                                   Auther          Score
# 0   Brandon Sanderson (Goodreads Author)  score: 33,030
# 1                           J.K. Rowling  score: 22,687
# 2      Rebecca Yarros (Goodreads Author)  score: 16,416
# 3       Leigh Bardugo (Goodreads Author)  score: 15,853
# 4       Sarah J. Maas (Goodreads Author)  score: 14,616
# ..                                   ...            ...
# 95                          Natsuki Kizu     score: 102
# 96                             J.D. Kirk      score: 77
# 97        Ladii Nesha (Goodreads Author)      score: 76
# 98       Mark Greaney (Goodreads Author)      score: 73
# 99      Robert Dugoni (Goodreads Author)      score: 71
#
# [100 rows x 3 columns]

# %%
df.to_excel(r'practis_webscraping.ipynb2.xlsx')

# %%
df1 = pd.read_excel("practis_webscraping.ipynb.xlsx")
df2 = pd.read_excel("practis_webscraping.ipynb2.xlsx")

# %%
df_merged = pd.concat([df1, df2], ignore_index=True)

# %%
df_merged.to_excel("books_merged.xlsx", index=False)

# %%
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

# %%
df.to_excel("books_clean.xlsx", index=False)
